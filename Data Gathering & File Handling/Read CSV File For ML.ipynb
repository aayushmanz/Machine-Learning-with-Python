# %% [markdown]
# ## 1. Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2. Opening a local csv file

# %%
df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv')
df.head()
# Out:
#    Season          Grand Prix  Round   Race Date  \
# 0    1950  British Grand Prix      1  1950-05-13
# 1    1950   Monaco Grand Prix      2  1950-05-21
# 2    1950    Indianapolis 500      3  1950-05-30
# 3    1950    Swiss Grand Prix      4  1950-06-04
# 4    1950  Belgian Grand Prix      5  1950-06-18
#
#                         Circuit         Country              Winner  \
# 0           Silverstone Circuit  United Kingdom     Giuseppe Farina
# 1             Circuit de Monaco          Monaco  Juan Manuel Fangio
# 2   Indianapolis Motor Speedway   United States     Johnnie Parsons
# 3            Circuit Bremgarten     Switzerland     Giuseppe Farina
# 4  Circuit de Spa-Francorchamps         Belgium  Juan Manuel Fangio
#
#   Second Place Driver Third Place Driver
# 0       Luigi Fagioli        Reg Parnell
# 1      Alberto Ascari       Louis Chiron
# 2        Bill Holland         Mauri Rose
# 3       Luigi Fagioli       Louis Rosier
# 4       Luigi Fagioli       Louis Rosier

# %% [markdown]
# ## 3. Opening a csv file from an url

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aayushmanz/Python-For-Data-Science/main/Database%20from%20Kaggle/kohli_ipl.csv')
df
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %% [markdown]
# ## 4. using sep Parameter :

# %%
df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/file.tsv', sep='\t')
df
# Out:
#           0    50  5  881250949
# 0         0   172  5  881250949
# 1         0   133  1  881250949
# 2       196   242  3  881250949
# 3       186   302  3  891717742
# 4        22   377  1  878887116
# ...     ...   ... ..        ...
# 99997   880   476  3  880175444
# 99998   716   204  5  879795543
# 99999   276  1090  1  874795795
# 100000   13   225  2  882399156
# 100001   12   203  3  879959583
#
# [100002 rows x 4 columns]

# %% [markdown]
# ## 5. Rename column in CSV :

# %%
# new way :

# this is just a dumpy don't take the columns name seriously
df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/file.tsv', sep='\t', names=['sno','name', 'release_year', 'number'])
df
# Out:
#         sno  name  release_year     number
# 0         0    50             5  881250949
# 1         0   172             5  881250949
# 2         0   133             1  881250949
# 3       196   242             3  881250949
# 4       186   302             3  891717742
# ...     ...   ...           ...        ...
# 99998   880   476             3  880175444
# 99999   716   204             5  879795543
# 100000  276  1090             1  874795795
# 100001   13   225             2  882399156
# 100002   12   203             3  879959583
#
# [100003 rows x 4 columns]

# %%
# old way :

df = pd.read_csv('https://raw.githubusercontent.com/aayushmanz/Python-For-Data-Science/main/Database%20from%20Kaggle/kohli_ipl.csv')
df.head()
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1

# %%
df = df.rename(columns={
    'match_no':'Match_No',
    'runs' : 'Runs'
})

df  # this more precise way to rename the columns.
# Out:
#      Match_No  Runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %% [markdown]
# ## 5. Index_col Parameter :

# %%
# new way :
pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv',index_col='Season' ).head()
# Out:
#                 Grand Prix  Round   Race Date                       Circuit  \
# Season
# 1950    British Grand Prix      1  1950-05-13           Silverstone Circuit
# 1950     Monaco Grand Prix      2  1950-05-21             Circuit de Monaco
# 1950      Indianapolis 500      3  1950-05-30   Indianapolis Motor Speedway
# 1950      Swiss Grand Prix      4  1950-06-04            Circuit Bremgarten
# 1950    Belgian Grand Prix      5  1950-06-18  Circuit de Spa-Francorchamps
#
#                Country              Winner Second Place Driver  \
# Season
# 1950    United Kingdom     Giuseppe Farina       Luigi Fagioli
# 1950            Monaco  Juan Manuel Fangio      Alberto Ascari
# 1950     United States     Johnnie Parsons        Bill Holland
# 1950       Switzerland     Giuseppe Farina       Luigi Fagioli
# 1950           Belgium  Juan Manuel Fangio       Luigi Fagioli
#
#        Third Place Driver
# Season
# 1950          Reg Parnell
# 1950         Louis Chiron
# ...

# %%
# old way ;

df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv')

df.set_index('Season').head() # old but far useful.
# Out:
#                 Grand Prix  Round   Race Date                       Circuit  \
# Season
# 1950    British Grand Prix      1  1950-05-13           Silverstone Circuit
# 1950     Monaco Grand Prix      2  1950-05-21             Circuit de Monaco
# 1950      Indianapolis 500      3  1950-05-30   Indianapolis Motor Speedway
# 1950      Swiss Grand Prix      4  1950-06-04            Circuit Bremgarten
# 1950    Belgian Grand Prix      5  1950-06-18  Circuit de Spa-Francorchamps
#
#                Country              Winner Second Place Driver  \
# Season
# 1950    United Kingdom     Giuseppe Farina       Luigi Fagioli
# 1950            Monaco  Juan Manuel Fangio      Alberto Ascari
# 1950     United States     Johnnie Parsons        Bill Holland
# 1950       Switzerland     Giuseppe Farina       Luigi Fagioli
# 1950           Belgium  Juan Manuel Fangio       Luigi Fagioli
#
#        Third Place Driver
# Season
# 1950          Reg Parnell
# 1950         Louis Chiron
# ...

# %% [markdown]
# ## 6. Header Parameter :

# %%
pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/test.csv', header=1)
# Out:
#              0  B B.1 B.2  C B.3 B.4  A  E E.1  ... 0.4767390451101133  \
# 0            5  A   B   A  C   B   C  A  E   C  ...           0.285509
# 1           15  B   A   A  A   B   B  A  E   D  ...           0.697272
# 2           16  B   B   A  C   B   D  A  E   A  ...           0.719306
# 3           17  B   B   A  C   B   C  A  E   C  ...           0.313032
# 4           19  B   B   B  C   B   B  A  E   E  ...           0.489711
# ...        ... ..  ..  .. ..  ..  .. .. ..  ..  ...                ...
# 199994  499987  B   A   A  C   B   D  A  E   E  ...           0.287454
# 199995  499990  B   A   A  C   B   B  A  E   C  ...           0.794881
# 199996  499991  A   B   B  C   B   B  A  E   C  ...           0.514487
# 199997  499994  A   A   A  C   B   D  A  D   A  ...           0.286144
# 199998  499995  A   A   A  C   B   D  A  E   A  ...           0.286755
#
#         0.37634964704960105  0.3378838967546349  0.3218317548420124  \
# ...

# %% [markdown]
# ## 7. use_cols parameter

# %%
# new way to use the read_csv for columns  

pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv', usecols=['Season','Country', 'Round'])
# Out:
#       Season  Round         Country
# 0       1950      1  United Kingdom
# 1       1950      2          Monaco
# 2       1950      3   United States
# 3       1950      4     Switzerland
# 4       1950      5         Belgium
# ...      ...    ...             ...
# 1153    2026      5          Canada
# 1154    2026      6          Monaco
# 1155    2026      7           Spain
# 1156    2026      8         Austria
# 1157    2026      9  United Kingdom
#
# [1158 rows x 3 columns]

# %%
# one more wayb to do that through iloc and loc 

df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv')
df[:,['Season', 'Country']] # df[['Season', 'Country']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:174, in pandas._libs.index.IndexEngine.get_loc()
# --> 174 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: '(slice(None, None, None), ['Season', 'Country'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[12], line 4
# ...

# %%
# iloc :

df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv')
df.iloc[:,1:4:1]
# Out:
#                           Grand Prix  Round   Race Date
# 0                 British Grand Prix      1  1950-05-13
# 1                  Monaco Grand Prix      2  1950-05-21
# 2                   Indianapolis 500      3  1950-05-30
# 3                   Swiss Grand Prix      4  1950-06-04
# 4                 Belgian Grand Prix      5  1950-06-18
# ...                              ...    ...         ...
# 1153             Canadian Grand Prix      5  2026-05-24
# 1154               Monaco Grand Prix      6  2026-06-07
# 1155  Barcelona-Catalunya Grand Prix      7  2026-06-14
# 1156             Austrian Grand Prix      8  2026-06-28
# 1157              British Grand Prix      9  2026-07-05
#
# [1158 rows x 3 columns]

# %% [markdown]
# ## 8. Squeeze parameter :

# %%
# df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv', usecols=['Country'], squeeze=True)
# squeeze is not avaiable for new update of pandas.

# %% [markdown]
# ## 9. Skiprows / nrows Parameter

# %%
df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv', skiprows=[0,1])
df
# Out:
#       1950               Monaco Grand Prix  2  1950-05-21  \
# 0     1950                Indianapolis 500  3  1950-05-30
# 1     1950                Swiss Grand Prix  4  1950-06-04
# 2     1950              Belgian Grand Prix  5  1950-06-18
# 3     1950               French Grand Prix  6  1950-07-02
# 4     1950              Italian Grand Prix  7  1950-09-03
# ...    ...                             ... ..         ...
# 1151  2026             Canadian Grand Prix  5  2026-05-24
# 1152  2026               Monaco Grand Prix  6  2026-06-07
# 1153  2026  Barcelona-Catalunya Grand Prix  7  2026-06-14
# 1154  2026             Austrian Grand Prix  8  2026-06-28
# 1155  2026              British Grand Prix  9  2026-07-05
#
#                    Circuit de Monaco          Monaco  Juan Manuel Fangio  \
# 0        Indianapolis Motor Speedway   United States     Johnnie Parsons
# 1                 Circuit Bremgarten     Switzerland     Giuseppe Farina
# ...

# %%
df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv', nrows=10)
df
# Out:
#    Season          Grand Prix  Round   Race Date  \
# 0    1950  British Grand Prix      1  1950-05-13
# 1    1950   Monaco Grand Prix      2  1950-05-21
# 2    1950    Indianapolis 500      3  1950-05-30
# 3    1950    Swiss Grand Prix      4  1950-06-04
# 4    1950  Belgian Grand Prix      5  1950-06-18
# 5    1950   French Grand Prix      6  1950-07-02
# 6    1950  Italian Grand Prix      7  1950-09-03
# 7    1951    Swiss Grand Prix      1  1951-05-27
# 8    1951    Indianapolis 500      2  1951-05-30
# 9    1951  Belgian Grand Prix      3  1951-06-17
#
#                         Circuit         Country              Winner  \
# 0           Silverstone Circuit  United Kingdom     Giuseppe Farina
# 1             Circuit de Monaco          Monaco  Juan Manuel Fangio
# 2   Indianapolis Motor Speedway   United States     Johnnie Parsons
# 3            Circuit Bremgarten     Switzerland     Giuseppe Farina
# 4  Circuit de Spa-Francorchamps         Belgium  Juan Manuel Fangio
# ...

# %% [markdown]
# ## 10. Encoding

# %%
df = pd.read_csv('/workspaces/Machine-Learning-with-Python/Data Gathering & File Handling/f1_podiums_1950_2026.csv', encoding='latin-1')
df.head(2)
# Out:
#    Season          Grand Prix  Round   Race Date              Circuit  \
# 0    1950  British Grand Prix      1  1950-05-13  Silverstone Circuit
# 1    1950   Monaco Grand Prix      2  1950-05-21    Circuit de Monaco
#
#           Country              Winner Second Place Driver Third Place Driver
# 0  United Kingdom     Giuseppe Farina       Luigi Fagioli        Reg Parnell
# 1          Monaco  Juan Manuel Fangio      Alberto Ascari       Louis Chiron

# %% [markdown]
# ## 11. dtypes parameter :
